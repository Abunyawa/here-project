# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import json

# %%
cities = {
    2: 'Nur-Sultan',
    1: 'Almaty',
    4: 'Aksay',
    6: 'Aktau',
    7: 'Aktobe',
    13: 'Atyrau',
    21: 'Esik',
    23: 'Janaozen',
    26: 'Jezkazgan',
    28: 'Jetysai',
    34: 'Kapchagai',
    35: 'Karaganda',
    39: 'Kaskelen',
    41: 'Kokshetau',
    90: 'Kordai',
    42: 'Kostanai',
    43: 'Kulsary',
    45: 'Kyzylorda',
    50: 'Pavlodar',
    51: 'Petropavlovsk',
    54: 'Rydnyi',
    57: 'Saryagash',
    58: 'Satpaev',
    59: 'Semei',
    65: 'Talgar',
    66: 'Taldykorgan',
    67: 'Taraz',
    70: 'Temirtau',
    71: 'Turkestan',
    72: 'Uralsk',
    73: 'Ust-Kamenogorsk',
    81: 'Shahtinsk',
    93: 'Shieli',
    84: 'Shymkent',
    85: 'Shuchinsk',
    86: 'Ekibastuz'
}

headers = {
'Host': 'kaspi.kz',
'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:77.0) Gecko/20100101 Firefox/77.0',
'Accept': 'application/json, text/javascript, */*; q=0.01',
'Accept-Language': 'en-US,en;q=0.5',
'Accept-Encoding': 'gzip, deflate, br',
'Content-Type': 'application/json; charset=utf-8',
'X-Requested-With': 'XMLHttpRequest',
'Connection': 'keep-alive',
'Referer': 'https://kaspi.kz/maps/terminals/',
'Cookie': 'k_stat=dl0rBeNwNXdsjnBU8U3r3y1nkr9r6; ssaid=0251ffa0-a944-11ea-90f2-f3b85cc6de47; test.user.group=15; maps_city=1; city_set_date=1591635215428; maps_city_set_date=1591772575176; _ga=GA1.2.232309656.1591592017; amp_3c7b23=sXifJGTMi71omHAnc4zM4I...1eabu03dv.1eabu777o.1.7.8; _fbp=fb.1.1591592019837.232127485; _hjid=bc0e3e98-959a-4aeb-800e-4a3d520ca306; user-device-type=Desktop; kaspi-payment-region=18; start-banners=%5B%7B%22Id%22%3A2%2C%22Position%22%3A1%2C%22IsNew%22%3Afalse%7D%2C%7B%22Id%22%3A9%2C%22Position%22%3A2%2C%22IsNew%22%3Afalse%7D%2C%7B%22Id%22%3A233%2C%22Position%22%3A3%2C%22IsNew%22%3Afalse%7D%5D; kaspi-region-confirm-shown=true; _dy_ses_load_seq=6605%3A1591685942121; _dy_csc_ses=t; _dy_c_exps=; _dy_soct=1014383.1024804.1591685942*1019791.1035034.1591685943; _gid=GA1.2.47053719.1591685943; _dycnst=dg; _dyid=-1941050497207160010; _dyfs=1591685943400; _dyjsession=9c697dc9031f1e0e899d835c7aa12dff; dy_fs_page=kaspi.kz; _dy_lu_ses=9c697dc9031f1e0e899d835c7aa12dff%3A1591685943401; _dycst=dk.l.f.ws.; _dy_geo=KZ.AS.KZ_.KZ__; _dy_df_geo=Kazakhstan..; _dy_toffset=-1; sessionid=rcuknt0qpk8vw6w1n08i0jwy79zdg7dk; __tld__=null'}

cookie = 'k_stat=dl0rBeNwNXdsjnBU8U3r3y1nkr9r6; ssaid=0251ffa0-a944-11ea-90f2-f3b85cc6de47; test.user.group=15; maps_city=1; city_set_date=1591635215428; maps_city_set_date=1591772575176; _ga=GA1.2.232309656.1591592017; amp_3c7b23=sXifJGTMi71omHAnc4zM4I...1eabu03dv.1eabu777o.1.7.8; _fbp=fb.1.1591592019837.232127485; _hjid=bc0e3e98-959a-4aeb-800e-4a3d520ca306; user-device-type=Desktop; kaspi-payment-region=18; start-banners=%5B%7B%22Id%22%3A2%2C%22Position%22%3A1%2C%22IsNew%22%3Afalse%7D%2C%7B%22Id%22%3A9%2C%22Position%22%3A2%2C%22IsNew%22%3Afalse%7D%2C%7B%22Id%22%3A233%2C%22Position%22%3A3%2C%22IsNew%22%3Afalse%7D%5D; kaspi-region-confirm-shown=true; _dy_ses_load_seq=6605%3A1591685942121; _dy_csc_ses=t; _dy_c_exps=; _dy_soct=1014383.1024804.1591685942*1019791.1035034.1591685943; _gid=GA1.2.47053719.1591685943; _dycnst=dg; _dyid=-1941050497207160010; _dyfs=1591685943400; _dyjsession=9c697dc9031f1e0e899d835c7aa12dff; dy_fs_page=kaspi.kz; _dy_lu_ses=9c697dc9031f1e0e899d835c7aa12dff%3A1591685943401; _dycst=dk.l.f.ws.; _dy_geo=KZ.AS.KZ_.KZ__; _dy_df_geo=Kazakhstan..; _dy_toffset=-1; sessionid=rcuknt0qpk8vw6w1n08i0jwy79zdg7dk; __tld__=null'



main = pd.DataFrame(columns=['id','address1','address2','latitude','longitude','status','city'])

for city in cities:
    cook = cookie.split(' maps_city=1; ')
    headers['Cookie'] = cook[0]+' maps_city={}; '.format(city)+cook[1] 
    url = 'https://kaspi.kz/maps/terminals/?page=1&term='
    resp = requests.get(url,headers = headers).json()
    num_of_pages = resp['num_of_pages']
    local_df = pd.DataFrame(columns=['id','address1','address2','latitude','longitude','status','city'])
    for page in range(1,num_of_pages+1):
        url = 'https://kaspi.kz/maps/terminals/?page={}&term='.format(str(page))
        resp = requests.get(url,headers = headers).json()
        local_df = local_df.append(pd.DataFrame(resp['terminals']),ignore_index = True)
    main = main.append(local_df)
    print(num_of_pages)
    local_df.to_csv('terminals_{}.csv'.format(cities[city]),index=None)
    
    
main.to_csv('terminals_all.csv',index=None)
# Out:
# 13
# 16
# 1
# 4
# 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-2aff34f87bb5> in <module>
#      65     for page in range(1,num_of_pages+1):
#      66         url = 'https://kaspi.kz/maps/terminals/?page={}&term='.format(str(page))
# ---> 67         resp = requests.get(url,headers = headers).json()
#      68         local_df = local_df.append(pd.DataFrame(resp['terminals']),ignore_index = True)
#      69     main = main.append(local_df)
#
# ~/Desktop/here-project/venv/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/Desktop/here-project/venv/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
# ...

# %%
headers = {
'Host': 'kaspi.kz',
'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:77.0) Gecko/20100101 Firefox/77.0',
'Accept': 'application/json, text/javascript, */*; q=0.01',
'Accept-Language': 'en-US,en;q=0.5',
'Accept-Encoding': 'gzip, deflate, br',
'Content-Type': 'application/json; charset=utf-8',
'X-Requested-With': 'XMLHttpRequest',
'Connection': 'keep-alive',
'Referer': 'https://kaspi.kz/maps/branches/',
'Cookie': 'k_stat=dl0rBeNwNXdsjnBU8U3r3y1nkr9r6; ssaid=0251ffa0-a944-11ea-90f2-f3b85cc6de47; test.user.group=15; maps_city=1; city_set_date=1591635215428; maps_city_set_date=1591772575176; _ga=GA1.2.232309656.1591592017; amp_3c7b23=sXifJGTMi71omHAnc4zM4I...1eabu03dv.1eabu777o.1.7.8; _fbp=fb.1.1591592019837.232127485; _hjid=bc0e3e98-959a-4aeb-800e-4a3d520ca306; user-device-type=Desktop; kaspi-payment-region=18; start-banners=%5B%7B%22Id%22%3A2%2C%22Position%22%3A1%2C%22IsNew%22%3Afalse%7D%2C%7B%22Id%22%3A9%2C%22Position%22%3A2%2C%22IsNew%22%3Afalse%7D%2C%7B%22Id%22%3A233%2C%22Position%22%3A3%2C%22IsNew%22%3Afalse%7D%5D; kaspi-region-confirm-shown=true; _dy_ses_load_seq=6605%3A1591685942121; _dy_csc_ses=t; _dy_c_exps=; _dy_soct=1014383.1024804.1591685942*1019791.1035034.1591685943; _gid=GA1.2.47053719.1591685943; _dycnst=dg; _dyid=-1941050497207160010; _dyfs=1591685943400; _dyjsession=9c697dc9031f1e0e899d835c7aa12dff; dy_fs_page=kaspi.kz; _dy_lu_ses=9c697dc9031f1e0e899d835c7aa12dff%3A1591685943401; _dycst=dk.l.f.ws.; _dy_geo=KZ.AS.KZ_.KZ__; _dy_df_geo=Kazakhstan..; _dy_toffset=-1; sessionid=rcuknt0qpk8vw6w1n08i0jwy79zdg7dk; __tld__=null'}

cookie = 'k_stat=dl0rBeNwNXdsjnBU8U3r3y1nkr9r6; ssaid=0251ffa0-a944-11ea-90f2-f3b85cc6de47; test.user.group=15; maps_city=1; city_set_date=1591635215428; maps_city_set_date=1591772575176; _ga=GA1.2.232309656.1591592017; amp_3c7b23=sXifJGTMi71omHAnc4zM4I...1eabu03dv.1eabu777o.1.7.8; _fbp=fb.1.1591592019837.232127485; _hjid=bc0e3e98-959a-4aeb-800e-4a3d520ca306; user-device-type=Desktop; kaspi-payment-region=18; start-banners=%5B%7B%22Id%22%3A2%2C%22Position%22%3A1%2C%22IsNew%22%3Afalse%7D%2C%7B%22Id%22%3A9%2C%22Position%22%3A2%2C%22IsNew%22%3Afalse%7D%2C%7B%22Id%22%3A233%2C%22Position%22%3A3%2C%22IsNew%22%3Afalse%7D%5D; kaspi-region-confirm-shown=true; _dy_ses_load_seq=6605%3A1591685942121; _dy_csc_ses=t; _dy_c_exps=; _dy_soct=1014383.1024804.1591685942*1019791.1035034.1591685943; _gid=GA1.2.47053719.1591685943; _dycnst=dg; _dyid=-1941050497207160010; _dyfs=1591685943400; _dyjsession=9c697dc9031f1e0e899d835c7aa12dff; dy_fs_page=kaspi.kz; _dy_lu_ses=9c697dc9031f1e0e899d835c7aa12dff%3A1591685943401; _dycst=dk.l.f.ws.; _dy_geo=KZ.AS.KZ_.KZ__; _dy_df_geo=Kazakhstan..; _dy_toffset=-1; sessionid=rcuknt0qpk8vw6w1n08i0jwy79zdg7dk; __tld__=null'



main = pd.DataFrame()

for city in cities:
    cook = cookie.split(' maps_city=1; ')
    headers['Cookie'] = cook[0]+' maps_city={}; '.format(city)+cook[1] 
    url = 'https://kaspi.kz/maps/branches/?page=1&term='
    resp = requests.get(url,headers = headers).json()
    num_of_pages = resp['num_of_pages']
    local_df = pd.DataFrame()
    for page in range(1,num_of_pages+1):
        url = 'https://kaspi.kz/maps/branches/?page={}&term='.format(str(page))
        resp = requests.get(url,headers = headers).json()
        local_df = local_df.append(pd.DataFrame(resp['branches']),ignore_index = True)
    main = main.append(local_df)
    local_df.to_csv('branches_{}.csv'.format(cities[city]),index=None)
    
    
main.to_csv('branches_all.csv',index=None)
# Out:
#     id                                           address1  \
# 0   13                     4 мкр-н, ул. К.Сатпаева, д. 10
# 1   17                         пр. Богенбай батыра, д. 6Б
# 2   10                 р-н Алматы, пр. Абылай Хана, д. 34
# 3    6                      р-н Алматы, ул. Иманова, д. 8
# 4   19                    р-н Алматы, ул. Кенесары, д. 78
# 5   15               р-н Алматы, ул. Ш. Валиханова, д. 24
# 6    8                р-н Есиль, ул. Достык, д. 12, ВП 36
# 7   23              р-н Есиль, ул. Кунаева, д. 14/2, ВП 1
# 8   22               р-н Есиль, ул. Сыганак, д. 10, ВП 27
# 9   11   р-н Сарыарка, пр. Богенбай батыра, д. 63, кв. 38
# 10   9               р-н Сарыарка, пр. Женис, д. 25, ВП 1
# 11  20             р-н Сарыарка, пр. Женис, д. 8/1, кв. 4
# 12  21    р-н Сарыарка, ул. Бейбитшилик, д. 36, кв. 22, 3
# 13   7  р-н Сарыарка, ул. Есенберлина (бывш. пр. Акжай...
# 14  12              р-н  Алматы, ул. Ш. Валиханова, д. 13
# ...

# %%
headers = {
'Host': 'kaspi.kz',
'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:77.0) Gecko/20100101 Firefox/77.0',
'Accept': 'application/json, text/javascript, */*; q=0.01',
'Accept-Language': 'en-US,en;q=0.5',
'Accept-Encoding': 'gzip, deflate, br',
'Content-Type': 'application/json; charset=utf-8',
'X-Requested-With': 'XMLHttpRequest',
'Connection': 'keep-alive',
'Referer': 'https://kaspi.kz/maps/atms/',
'Cookie': 'k_stat=dl0rBeNwNXdsjnBU8U3r3y1nkr9r6; ssaid=0251ffa0-a944-11ea-90f2-f3b85cc6de47; test.user.group=15; maps_city=1; city_set_date=1591635215428; maps_city_set_date=1591772575176; _ga=GA1.2.232309656.1591592017; amp_3c7b23=sXifJGTMi71omHAnc4zM4I...1eabu03dv.1eabu777o.1.7.8; _fbp=fb.1.1591592019837.232127485; _hjid=bc0e3e98-959a-4aeb-800e-4a3d520ca306; user-device-type=Desktop; kaspi-payment-region=18; start-banners=%5B%7B%22Id%22%3A2%2C%22Position%22%3A1%2C%22IsNew%22%3Afalse%7D%2C%7B%22Id%22%3A9%2C%22Position%22%3A2%2C%22IsNew%22%3Afalse%7D%2C%7B%22Id%22%3A233%2C%22Position%22%3A3%2C%22IsNew%22%3Afalse%7D%5D; kaspi-region-confirm-shown=true; _dy_ses_load_seq=6605%3A1591685942121; _dy_csc_ses=t; _dy_c_exps=; _dy_soct=1014383.1024804.1591685942*1019791.1035034.1591685943; _gid=GA1.2.47053719.1591685943; _dycnst=dg; _dyid=-1941050497207160010; _dyfs=1591685943400; _dyjsession=9c697dc9031f1e0e899d835c7aa12dff; dy_fs_page=kaspi.kz; _dy_lu_ses=9c697dc9031f1e0e899d835c7aa12dff%3A1591685943401; _dycst=dk.l.f.ws.; _dy_geo=KZ.AS.KZ_.KZ__; _dy_df_geo=Kazakhstan..; _dy_toffset=-1; sessionid=rcuknt0qpk8vw6w1n08i0jwy79zdg7dk; __tld__=null'}

cookie = 'k_stat=dl0rBeNwNXdsjnBU8U3r3y1nkr9r6; ssaid=0251ffa0-a944-11ea-90f2-f3b85cc6de47; test.user.group=15; maps_city=1; city_set_date=1591635215428; maps_city_set_date=1591772575176; _ga=GA1.2.232309656.1591592017; amp_3c7b23=sXifJGTMi71omHAnc4zM4I...1eabu03dv.1eabu777o.1.7.8; _fbp=fb.1.1591592019837.232127485; _hjid=bc0e3e98-959a-4aeb-800e-4a3d520ca306; user-device-type=Desktop; kaspi-payment-region=18; start-banners=%5B%7B%22Id%22%3A2%2C%22Position%22%3A1%2C%22IsNew%22%3Afalse%7D%2C%7B%22Id%22%3A9%2C%22Position%22%3A2%2C%22IsNew%22%3Afalse%7D%2C%7B%22Id%22%3A233%2C%22Position%22%3A3%2C%22IsNew%22%3Afalse%7D%5D; kaspi-region-confirm-shown=true; _dy_ses_load_seq=6605%3A1591685942121; _dy_csc_ses=t; _dy_c_exps=; _dy_soct=1014383.1024804.1591685942*1019791.1035034.1591685943; _gid=GA1.2.47053719.1591685943; _dycnst=dg; _dyid=-1941050497207160010; _dyfs=1591685943400; _dyjsession=9c697dc9031f1e0e899d835c7aa12dff; dy_fs_page=kaspi.kz; _dy_lu_ses=9c697dc9031f1e0e899d835c7aa12dff%3A1591685943401; _dycst=dk.l.f.ws.; _dy_geo=KZ.AS.KZ_.KZ__; _dy_df_geo=Kazakhstan..; _dy_toffset=-1; sessionid=rcuknt0qpk8vw6w1n08i0jwy79zdg7dk; __tld__=null'



main = pd.DataFrame()

for city in cities:
    cook = cookie.split(' maps_city=1; ')
    headers['Cookie'] = cook[0]+' maps_city={}; '.format(city)+cook[1] 
    url = 'https://kaspi.kz/maps/atms/?page=1&term='
    resp = requests.get(url,headers = headers).json()
    num_of_pages = resp['num_of_pages']
    local_df = pd.DataFrame()
    for page in range(1,num_of_pages+1):
        url = 'https://kaspi.kz/maps/atms/?page={}&term='.format(str(page))
        resp = requests.get(url,headers = headers).json()
        local_df = local_df.append(pd.DataFrame(resp['atms']),ignore_index = True)
    main = main.append(local_df)
    local_df.to_csv('atms_{}.csv'.format(cities[city]),index=None)
    
    
main.to_csv('atms_all.csv',index=None)

# %%
headers = {
'Host': 'kaspi.kz',
'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:77.0) Gecko/20100101 Firefox/77.0',
'Accept': 'application/json, text/javascript, */*; q=0.01',
'Accept-Language': 'en-US,en;q=0.5',
'Accept-Encoding': 'gzip, deflate, br',
'Content-Type': 'application/json; charset=utf-8',
'X-Requested-With': 'XMLHttpRequest',
'Connection': 'keep-alive',
'Referer': 'https://kaspi.kz/maps/autoservices/',
'Cookie': 'k_stat=dl0rBeNwNXdsjnBU8U3r3y1nkr9r6; ssaid=0251ffa0-a944-11ea-90f2-f3b85cc6de47; test.user.group=15; maps_city=1; city_set_date=1591635215428; maps_city_set_date=1591772575176; _ga=GA1.2.232309656.1591592017; amp_3c7b23=sXifJGTMi71omHAnc4zM4I...1eabu03dv.1eabu777o.1.7.8; _fbp=fb.1.1591592019837.232127485; _hjid=bc0e3e98-959a-4aeb-800e-4a3d520ca306; user-device-type=Desktop; kaspi-payment-region=18; start-banners=%5B%7B%22Id%22%3A2%2C%22Position%22%3A1%2C%22IsNew%22%3Afalse%7D%2C%7B%22Id%22%3A9%2C%22Position%22%3A2%2C%22IsNew%22%3Afalse%7D%2C%7B%22Id%22%3A233%2C%22Position%22%3A3%2C%22IsNew%22%3Afalse%7D%5D; kaspi-region-confirm-shown=true; _dy_ses_load_seq=6605%3A1591685942121; _dy_csc_ses=t; _dy_c_exps=; _dy_soct=1014383.1024804.1591685942*1019791.1035034.1591685943; _gid=GA1.2.47053719.1591685943; _dycnst=dg; _dyid=-1941050497207160010; _dyfs=1591685943400; _dyjsession=9c697dc9031f1e0e899d835c7aa12dff; dy_fs_page=kaspi.kz; _dy_lu_ses=9c697dc9031f1e0e899d835c7aa12dff%3A1591685943401; _dycst=dk.l.f.ws.; _dy_geo=KZ.AS.KZ_.KZ__; _dy_df_geo=Kazakhstan..; _dy_toffset=-1; sessionid=rcuknt0qpk8vw6w1n08i0jwy79zdg7dk; __tld__=null'}

cookie = 'k_stat=dl0rBeNwNXdsjnBU8U3r3y1nkr9r6; ssaid=0251ffa0-a944-11ea-90f2-f3b85cc6de47; test.user.group=15; maps_city=1; city_set_date=1591635215428; maps_city_set_date=1591772575176; _ga=GA1.2.232309656.1591592017; amp_3c7b23=sXifJGTMi71omHAnc4zM4I...1eabu03dv.1eabu777o.1.7.8; _fbp=fb.1.1591592019837.232127485; _hjid=bc0e3e98-959a-4aeb-800e-4a3d520ca306; user-device-type=Desktop; kaspi-payment-region=18; start-banners=%5B%7B%22Id%22%3A2%2C%22Position%22%3A1%2C%22IsNew%22%3Afalse%7D%2C%7B%22Id%22%3A9%2C%22Position%22%3A2%2C%22IsNew%22%3Afalse%7D%2C%7B%22Id%22%3A233%2C%22Position%22%3A3%2C%22IsNew%22%3Afalse%7D%5D; kaspi-region-confirm-shown=true; _dy_ses_load_seq=6605%3A1591685942121; _dy_csc_ses=t; _dy_c_exps=; _dy_soct=1014383.1024804.1591685942*1019791.1035034.1591685943; _gid=GA1.2.47053719.1591685943; _dycnst=dg; _dyid=-1941050497207160010; _dyfs=1591685943400; _dyjsession=9c697dc9031f1e0e899d835c7aa12dff; dy_fs_page=kaspi.kz; _dy_lu_ses=9c697dc9031f1e0e899d835c7aa12dff%3A1591685943401; _dycst=dk.l.f.ws.; _dy_geo=KZ.AS.KZ_.KZ__; _dy_df_geo=Kazakhstan..; _dy_toffset=-1; sessionid=rcuknt0qpk8vw6w1n08i0jwy79zdg7dk; __tld__=null'



main = pd.DataFrame()

for city in cities:
    cook = cookie.split(' maps_city=1; ')
    headers['Cookie'] = cook[0]+' maps_city={}; '.format(city)+cook[1] 
    url = 'https://kaspi.kz/maps/autoservices/?page=1&term='
    resp = requests.get(url,headers = headers).json()
    num_of_pages = resp['num_of_pages']
    local_df = pd.DataFrame()
    for page in range(1,num_of_pages+1):
        url = 'https://kaspi.kz/maps/autoservices/?page={}&term='.format(str(page))
        resp = requests.get(url,headers = headers).json()
        local_df = local_df.append(pd.DataFrame(resp['mt_points']),ignore_index = True)
    main = main.append(local_df)
    local_df.to_csv('autoservices_{}.csv'.format(cities[city]),index=None)
    
    
main.to_csv('autoservices_all.csv',index=None)
